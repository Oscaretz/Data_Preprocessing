# %%
#Importamos Pandas y nuestro archivo CSV a trabajar, renombrado  'ent'.
#Aplicamos el codec 'ISO-8859-1' para poder visualzar correctamente todos los caractéres del CSV.
import pandas as pd
ent = pd.read_csv("C:/Users/User/Documents/UPY/Data Preproccesing/Symmary_Unit1/INE_ENTIDAD_2020.csv", index_col=0, encoding = 'ISO-8859-1')
ent
# Out:
#                             NOM_ENT     POBTOT   POBFEM   POBMAS   P_0A2  \
# ENT
# 1                     Aguascalientes   1425607   728924   696683   71864
# 2                    Baja California   3769020  1868431  1900589  149957
# 3                Baja California Sur    798447   392568   405879   35963
# 4                           Campeche    928363   471424   456939   45541
# 5               Coahuila de Zaragoza   3146771  1583102  1563669  160368
# 6                             Colima    731391   370769   360622   29614
# 7                            Chiapas   5543828  2837881  2705947  334055
# 8                          Chihuahua   3741869  1888047  1853822  163950
# 9                   Ciudad de México   9209944  4805017  4404927  267151
# 10                           Durango   1832650   927784   904866   95793
# 11                        Guanajuato   6166934  3170480  2996454  313928
# 12                          Guerrero   3540685  1840073  1700612  197506
# ...

# %%
#Renombramos nuestra data base 'sec' a 'df' y visualizamos las columnas.
#En la tabla no contamos con datos categóricos para poder crear los dummys.
df = ent
df.columns
# Out:
# Index(['NOM_ENT ', 'POBTOT', 'POBFEM', 'POBMAS', 'P_0A2', 'P_0A2_F', 'P_0A2_M',
#        'P_0A17', 'P_3YMAS', 'P_3YMAS_F',
#        ...
#        'VPH_TELEF', 'VPH_CEL', 'VPH_INTER', 'VPH_STVP', 'VPH_SPMVPI',
#        'VPH_CVJ', 'VPH_SINRTV', 'VPH_SINLTC', 'VPH_SINCIN', 'VPH_SINTIC'],
#       dtype='object', length=221)

# %%
#Checamos las tendencias de los valores
df.describe()
# Out:
#              POBTOT        POBFEM        POBMAS          P_0A2        P_0A2_F  \
# count  3.200000e+01  3.200000e+01  3.200000e+01      32.000000      32.000000
# mean   3.937938e+06  2.016895e+06  1.921043e+06  180126.687500   89027.343750
# std    3.278009e+06  1.692778e+06  1.585771e+06  140571.778417   69526.362605
# min    7.313910e+05  3.707690e+05  3.606220e+05   29614.000000   14483.000000
# 25%    1.851651e+06  9.261395e+05  9.288008e+05   87423.000000   43210.000000
# 50%    3.054892e+06  1.557615e+06  1.488097e+06  137070.500000   67647.500000
# 75%    4.947592e+06  2.541349e+06  2.406242e+06  253391.500000  125469.500000
# max    1.699242e+07  8.741123e+06  8.251295e+06  724133.000000  357766.000000
#
#              P_0A2_M        P_0A17       P_3YMAS     P_3YMAS_F     P_3YMAS_M  \
# count      32.000000  3.200000e+01  3.200000e+01  3.200000e+01  3.200000e+01
# mean    91099.343750  1.195249e+06  3.749268e+06  1.923580e+06  1.825688e+06
# ...

# %%
#Comprobamos los tipos de datos de cada columna.
df.dtypes
# Out:
# NOM_ENT       object
# POBTOT         int64
# POBFEM         int64
# POBMAS         int64
# P_0A2          int64
#                ...
# VPH_CVJ        int64
# VPH_SINRTV     int64
# VPH_SINLTC     int64
# VPH_SINCIN     int64
# VPH_SINTIC     int64
# Length: 221, dtype: object

# %%
#Verificamos si hay missing values en cada columna.
missing_values_count = df.isnull().sum()
missing_values_count
# Out:
# NOM_ENT       0
# POBTOT        0
# POBFEM        0
# POBMAS        0
# P_0A2         0
#              ..
# VPH_CVJ       0
# VPH_SINRTV    0
# VPH_SINLTC    0
# VPH_SINCIN    0
# VPH_SINTIC    0
# Length: 221, dtype: int64

# %%
#Imprimimos el total de missing values.
missing_total = missing_values_count.sum()
print('Total missing values: ', missing_total)
# Out:
# Total missing values:  0

# %%
#Verificamos si hay filas duplicadas e imprimimos el total.
duplicated_values = df.duplicated().sum()
print('Total duplicated rows: ', duplicated_values)
# Out:
# Total duplicated rows:  0
